# %% [markdown]
# <img src=".\images\Logo.png" width=150 align="left" /> <img src=".\images\Logo2.jpg" width=450 align="right" />

# %% [markdown]
# # <center><font color= #1e8449 > <b>CUxx_Nombre del caso de uso</font></center>

# %% [markdown]
# <font color='steelblue'><b>Citizenlab Data Science Methodology > II - Data Processing Domain </font>
# ***
# > # <font color='steelblue'> <b>13.01.- Simple Data Visualization</font>

# %% [markdown]
# <font color='steelblue'>Data Visualization is the process of performing a statistical graphical analysis of the data.

# %% [markdown]
# ## <font color='green'>Settings</font>

# %%
# Libraries to use
import os
from pathlib import Path
import pandas as pd
import easygui as GUI
import seaborn as sn
import matplotlib.pyplot as plt
import dabl
# Out:
# C:\Users\Eugenio\anaconda3\envs\kapreolus\lib\site-packages\sklearn\experimental\enable_hist_gradient_boosting.py:17: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   "Since version 1.0, "

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## <font color='green'>Data Load</font>

# %% [markdown]
# <font color='tomato'><b> OPCION A:</b> Uso de la librería "easygui" para mayor comodidad</font>

# %%
# Data load using "easygui" library
file_data=GUI.fileopenbox(title='Open Data File', default="Data/Input/", filetypes="*.*")

# %% [markdown]
# <font color='tomato'>Utilizamos en todos los notebooks SIEMPRE <b>data</b> como nombre de la matriz (dataframe) principal donde cargamos los datos.</font>

# %%
# Data file to dataframe
data = pd.read_csv(file_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # Data file to dataframe
# ----> 2 data = pd.read_csv(file_data)
#
# NameError: name 'pd' is not defined

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %% [markdown]
# <font color='tomato'><b> OPCION B:</b> Directamente</font>

# %%
file_name='diabetes.csv'
data = pd.read_csv('Data/Input/'+file_name)

# %% [markdown]
# <font color='tomato'>Visualizo los datos.</font>

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Line plot

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Scatter plot

# %%
''' INTRO: ESPECIFICAR LAS COLUMNAS QUE SE DESEAN'''
''' Los nombre de las columnas son case sensitive'''
data.plot.scatter(x='Plasma', y='Age')

# %% [markdown]
# ### Area plot

# %%
data.plot.area();

# %%
''' INTRO: ESPECIFICAR LAS COLUMNAS QUE SE DESEAN'''
''' Los nombre de las columnas son case sensitive'''
columns = ['Plasma', 'Age']
data[columns].plot.area()

# %% [markdown]
# ### Bar chart

# %%
data.plot.bar();

# %%
data.plot.bar(stacked=True);

# %%
data.plot.barh();

# %%
data.plot.barh(stacked=True)

# %%
''' INTRO: ESPECIFICAR LAS COLUMNAS QUE SE DESEAN'''
''' Los nombre de las columnas son case sensitive'''
data.groupby('Age').mean().plot.bar()

# %% [markdown]
# ### Piechart

# %%
''' INTRO: ESPECIFICAR LAS COLUMNAS QUE SE DESEAN'''
''' Los nombre de las columnas son case sensitive'''
data.groupby('Plasma').count().plot.pie(y='Age')

# %% [markdown]
# ### Histogram

# %%
data.hist()
plt.tight_layout()

# %% [markdown]
# ### Kernel density function

# %%
x=data.plot.kde(subplots=True, figsize=(5,9))

# %%
''' INTRO: ESPECIFICAR LA COLUMNA QUE SE DESEA'''
''' Los nombre de las columnas son case sensitive'''
sn.kdeplot(data['Plasma'], shade=True, color='orangered')

# %% [markdown]
# ### Boxplot

# %%
x=data.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(20, 20), color='deeppink')

# %%
''' INTRO: ESPECIFICAR LAS COLUMNAS QUE SE DESEAN'''
''' Los nombre de las columnas son case sensitive'''
columns = ['Plasma', 'Age']
data[columns].plot.box()
plt.xticks(rotation='vertical')
# Out:
# (array([1, 2]), <a list of 2 Text major ticklabel objects>)

# %% [markdown]
# ### Scatter matrix plot

# %%
sn.pairplot(data)

# %%
sn.scatterplot(x='Plasma', y='Age', data=data, hue='Age')

# %% [markdown]
# ### Quantitative and qualitative variable relationships

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.violinplot.html

# %%
sn.violinplot(x='Plasma', y='Age', hue="Target", data=data);

# %% [markdown]
# ### Violin plot

# %%
x = sns.violinplot(x=data["satisfaction_level"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2776\2561939497.py in <module>
# ----> 1 x = sns.violinplot(x=data["satisfaction_level"])
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ### Other Visualization

# %%
data.head()
# Out:
#    NPregnant  Plasma  Diastolic  Triceps  Serum  Body  Pedigree  Age  Target
# 0          6     148         72       35      0  33.6     0.627   50       1
# 1          1      85         66       29      0  26.6     0.351   31       0
# 2          8     183         64        0      0  23.3     0.672   32       1
# 3          1      89         66       23     94  28.1     0.167   21       0
# 4          0     137         40       35    168  43.1     2.288   33       1

# %%
import dabl
''' INTRO: ESPECIFICAR LAS COLUMNAS QUE SE DESEAN'''
''' Los nombre de las columnas son case sensitive'''
dabl.plot(data, 'Plasma')
# Out:
# Target looks like regression
# C:\Users\Eugenio\Anaconda3\envs\pycaretenv\lib\site-packages\dabl\plot\supervised.py:528: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   FutureWarning)
# C:\Users\Eugenio\Anaconda3\envs\pycaretenv\lib\site-packages\dabl\plot\utils.py:621: UserWarning: Dropped 1 outliers in column Serum.
#   int(dropped), series.name), UserWarning)
# C:\Users\Eugenio\Anaconda3\envs\pycaretenv\lib\site-packages\dabl\plot\utils.py:621: UserWarning: Dropped 1 outliers in column Triceps.
#   int(dropped), series.name), UserWarning)

# %%
X=data.drop(columns=['Target'])
y=data.Target
dabl.plot(X, y)
plt.show()
# Out:
# Target looks like classification
# C:\Users\Eugenio\Anaconda3\envs\pycaretenv\lib\site-packages\dabl\plot\utils.py:621: UserWarning: Dropped 1 outliers in column Serum.
#   int(dropped), series.name), UserWarning)
# C:\Users\Eugenio\Anaconda3\envs\pycaretenv\lib\site-packages\dabl\plot\utils.py:621: UserWarning: Dropped 1 outliers in column Triceps.
#   int(dropped), series.name), UserWarning)
# Linear Discriminant Analysis training set score: 0.737
