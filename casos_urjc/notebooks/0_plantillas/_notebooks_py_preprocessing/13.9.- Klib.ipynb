# %% [markdown]
# <img src=".\images\Logo.png" width=150 align="left" /> <img src=".\images\Logo2.jpg" width=450 align="right" />

# %% [markdown]
# # <center><font color= #1e8449 > <b>CUxx_Nombre del caso de uso</font></center>

# %% [markdown]
# <font color='steelblue'><b>Citizenlab Data Science Methodology > II - Data Processing Domain </font>
# ***
# > # <font color='steelblue'> <b>13.09.- Klib</font>

# %% [markdown]
# <font color='steelblue'>Data Visualization is the process of performing a statistical graphical analysis of the data..

# %% [markdown]
# klib is a Python library for importing, cleaning, analyzing, and preprocessing the data.
#
# https://klib.readthedocs.io/en/latest/
#
# https://medium.com/geekculture/10-automated-eda-libraries-at-one-place-ea5d4c162bbb

# %% [markdown]
# ## <font color='green'>Settings</font>

# %%
# Libraries to use
import os
from pathlib import Path
import pandas as pd
import easygui as GUI
import klib

# %% [markdown]
# ## <font color='green'>Data Load</font>

# %% [markdown]
# <font color='tomato'><b> OPCION A:</b> Uso de la librería "easygui" para mayor comodidad</font>

# %%
# Data load using "easygui" library
file_data=GUI.fileopenbox(title='Open Data File', default="Data/Input/", filetypes="*.*")

# %% [markdown]
# <font color='tomato'>Utilizamos en todos los notebooks SIEMPRE <b>data</b> como nombre de la matriz (dataframe) principal donde cargamos los datos.</font>

# %%
# Data file to dataframe
data = pd.read_csv(file_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # Data file to dataframe
# ----> 2 data = pd.read_csv(file_data)
#
# NameError: name 'pd' is not defined

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %% [markdown]
# <font color='tomato'><b> OPCION B:</b> Directamente</font>

# %%
file_name='diabetes.csv'
data = pd.read_csv('Data/Input/'+file_name)

# %% [markdown]
# <font color='tomato'>Visualizo los datos.</font>

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Klib

# %%
# returns a visualization of the number and frequency of categorical features
klib.cat_plot(data)
# Out:
# GridSpec(6, 2)

# %%
# returns a color-encoded correlation matrix
klib.corr_mat(data)
# Out:
# <style type="text/css">
# #T_489f1_row0_col0, #T_489f1_row0_col1, #T_489f1_row0_col5, #T_489f1_row0_col6, #T_489f1_row1_col0, #T_489f1_row1_col1, #T_489f1_row1_col2, #T_489f1_row1_col3, #T_489f1_row1_col4, #T_489f1_row1_col7, #T_489f1_row2_col1, #T_489f1_row2_col2, #T_489f1_row2_col3, #T_489f1_row2_col4, #T_489f1_row2_col7, #T_489f1_row3_col1, #T_489f1_row3_col2, #T_489f1_row3_col3, #T_489f1_row3_col4, #T_489f1_row3_col7, #T_489f1_row4_col1, #T_489f1_row4_col2, #T_489f1_row4_col3, #T_489f1_row4_col4, #T_489f1_row4_col5, #T_489f1_row4_col6, #T_489f1_row4_col7, #T_489f1_row5_col0, #T_489f1_row5_col4, #T_489f1_row5_col5, #T_489f1_row5_col6, #T_489f1_row6_col0, #T_489f1_row6_col4, #T_489f1_row6_col5, #T_489f1_row6_col6, #T_489f1_row7_col1, #T_489f1_row7_col2, #T_489f1_row7_col3, #T_489f1_row7_col4, #T_489f1_row7_col7 {
#   color: None;
# }
# ...

# %%
# returns a color-encoded heatmap, ideal for correlations
klib.corr_plot(data)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
# displaying only positive correlations, other settings include threshold
klib.corr_plot(data, split='pos')
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
# displaying only negative correlations
klib.corr_plot(data, split='neg')
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
# default representation of correlations with the feature column
klib.corr_plot(data, target='left')
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
# returns a distribution plot for every numeric feature
klib.dist_plot(data)
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='time_spend_company', ylabel='Density'>

# %%
# returns a figure containing information about missing values
klib.missingval_plot(data)
# Out:
# No missing values found in the dataset.

# %%
# representation of the 4 most & least common values in each categorical column
klib.cat_plot(data, top=4, bottom=4)
# Out:
# GridSpec(6, 2)
